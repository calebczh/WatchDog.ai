# %%
# !pip install send2trash
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: send2trash in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.8.0)

# %% [markdown]
# #### Pre. Downloading Images With ToolKit

# %%
# !git clone https://github.com/theAIGuysCode/OIDv4_ToolKit.git
# !pip3 install -r OIDv4_ToolKit/requirements.txt
# !python OIDv4_ToolKit/main.py downloader --classes Monkey Otter Dog --type_csv train --limit 1000 --y
# convert into YOLO format
# !python OIDv4_ToolKit/main.py downloader --classes Monkey Otter Dog --type_csv test --limit 100 --y
# !python OIDv4_ToolKit/main.py downloader --classes Monkey Otter Dog --type_csv validation --limit 100 --y
# !python OIDv4_ToolKit/convert_annotations.py
# Out:
# fatal: destination path 'OIDv4_ToolKit' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: awscli in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 3)) (1.27.71)
# Requirement already satisfied: urllib3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 4)) (1.26.15)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 5)) (4.64.1)
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from -r OIDv4_ToolKit/requirements.txt (line 6)) (4.7.0.68)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pandas->-r OIDv4_ToolKit/requirements.txt (line 1)) (2022.7)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pandas->-r OIDv4_ToolKit/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: docutils<0.17,>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (0.16)
# Requirement already satisfied: botocore==1.29.71 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (1.29.71)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (4.7.2)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (5.4.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from botocore==1.29.71->awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas->-r OIDv4_ToolKit/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from rsa<4.8,>=3.1.2->awscli->-r OIDv4_ToolKit/requirements.txt (line 3)) (0.4.8)
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Monkey.
#
# -------------------------------------Monkey-------------------------------------
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 2143 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 532 images in train.
# 100%|█████████████████████████████████████████| 532/532 [01:26<00:00,  6.18it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Monkey of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Otter.
#
# -------------------------------------Otter-------------------------------------
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 487 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | All images already downloaded.
#     [INFO] | Creating labels for Otter of train.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Dog.
#
# --------------------------------------Dog--------------------------------------
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 20607 online images for train.
#     [INFO] | Limiting to 1000 images.
#     [INFO] | Download of 962 images in train.
# 100%|█████████████████████████████████████████| 962/962 [02:32<00:00,  6.31it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Dog of train.
#     [INFO] | Labels creation completed.
# Currently in subdirectory: train
# Converting annotations for class:  Dog
# 100%|███████████████████████████████████████| 1896/1896 [00:31<00:00, 59.52it/s]
# Converting annotations for class:  Monkey
# 100%|███████████████████████████████████████| 1532/1532 [00:25<00:00, 59.28it/s]
# Converting annotations for class:  Otter
# 100%|█████████████████████████████████████████| 487/487 [00:09<00:00, 50.24it/s]
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Monkey.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Automatic download.
# ...100%, 49 MB, 17896 KB/s, 2 seconds passed
# [DOWNLOAD] | File test-annotations-bbox.csv downloaded into OID/csv_folder/test-annotations-bbox.csv.
#
# -------------------------------------Monkey-------------------------------------
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 422 online images for test.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in test.
# 100%|█████████████████████████████████████████| 100/100 [00:17<00:00,  5.57it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Monkey of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Otter.
#
# -------------------------------------Otter-------------------------------------
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 118 online images for test.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in test.
# 100%|█████████████████████████████████████████| 100/100 [00:17<00:00,  5.74it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Otter of test.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Dog.
#
# --------------------------------------Dog--------------------------------------
#     [INFO] | Downloading test images.
#     [INFO] | [INFO] Found 4810 online images for test.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in test.
# 100%|█████████████████████████████████████████| 100/100 [00:17<00:00,  5.63it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Dog of test.
#     [INFO] | Labels creation completed.
# Currently in subdirectory: train
# Converting annotations for class:  Dog
# 100%|███████████████████████████████████████| 1896/1896 [00:31<00:00, 59.52it/s]
# Converting annotations for class:  Monkey
# 100%|███████████████████████████████████████| 1532/1532 [00:25<00:00, 59.25it/s]
# Converting annotations for class:  Otter
# 100%|█████████████████████████████████████████| 487/487 [00:09<00:00, 50.20it/s]
# Currently in subdirectory: test
# Converting annotations for class:  Dog
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 70.12it/s]
# Converting annotations for class:  Monkey
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 63.69it/s]
# Converting annotations for class:  Otter
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 65.54it/s]
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Monkey.
#    [ERROR] | Missing the validation-annotations-bbox.csv file.
# [DOWNLOAD] | Automatic download.
# ...100%, 16 MB, 11418 KB/s, 1 seconds passed
# [DOWNLOAD] | File validation-annotations-bbox.csv downloaded into OID/csv_folder/validation-annotations-bbox.csv.
#
# -------------------------------------Monkey-------------------------------------
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 152 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in validation.
# 100%|█████████████████████████████████████████| 100/100 [00:17<00:00,  5.71it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Monkey of validation.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Otter.
#
# -------------------------------------Otter-------------------------------------
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 32 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 32 images in validation.
# 100%|███████████████████████████████████████████| 32/32 [00:06<00:00,  4.73it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Otter of validation.
#     [INFO] | Labels creation completed.
#     [INFO] | Downloading Dog.
#
# --------------------------------------Dog--------------------------------------
#     [INFO] | Downloading validation images.
#     [INFO] | [INFO] Found 1581 online images for validation.
#     [INFO] | Limiting to 100 images.
#     [INFO] | Download of 100 images in validation.
# 100%|█████████████████████████████████████████| 100/100 [00:16<00:00,  5.89it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Dog of validation.
#     [INFO] | Labels creation completed.
# Currently in subdirectory: train
# Converting annotations for class:  Dog
# 100%|███████████████████████████████████████| 1896/1896 [00:31<00:00, 59.34it/s]
# Converting annotations for class:  Monkey
# 100%|███████████████████████████████████████| 1532/1532 [00:25<00:00, 59.23it/s]
# Converting annotations for class:  Otter
# 100%|█████████████████████████████████████████| 487/487 [00:09<00:00, 50.12it/s]
# Currently in subdirectory: validation
# Converting annotations for class:  Dog
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 67.82it/s]
# Converting annotations for class:  Monkey
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 63.79it/s]
# Converting annotations for class:  Otter
# 100%|███████████████████████████████████████████| 32/32 [00:00<00:00, 72.58it/s]
# Currently in subdirectory: test
# Converting annotations for class:  Dog
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 70.01it/s]
# Converting annotations for class:  Monkey
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 63.52it/s]
# Converting annotations for class:  Otter
# 100%|█████████████████████████████████████████| 100/100 [00:01<00:00, 65.26it/s]

# %%
# !pip3 install ultralytics
from ultralytics import YOLO

# !yolo task=detect mode=train model=yolov8s.pt data="dataset.yaml" epochs=10 imgsz=640 batch=8 project="train_result" name=monkey
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: ultralytics in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (8.0.52)
# Requirement already satisfied: sentry-sdk in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: torchvision>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.14.1)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: scipy>=1.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.7.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (4.7.0.68)
# Requirement already satisfied: requests>=2.23.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: Pillow>=7.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (3.5.3)
# Requirement already satisfied: tqdm>=4.64.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: thop>=0.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (5.4.1)
# Requirement already satisfied: numpy>=1.18.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.21.6)
# Requirement already satisfied: torch>=1.7.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: pandas>=1.1.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.3.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from seaborn>=0.11.0->ultralytics) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.10.3.66)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (8.5.0.96)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->ultralytics) (65.6.3)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->ultralytics) (0.38.4)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# New https://pypi.org/project/ultralytics/8.0.53 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.52 🚀 Python-3.7.10 torch-1.13.1+cu117 CPU
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=dataset.yaml, epochs=10, patience=50, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=train_result, name=monkey, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=train_result/monkey19
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2117209  ultralytics.nn.modules.Detect                [3, [128, 256, 512]]
# Model summary: 225 layers, 11136761 parameters, 11136745 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# WARNING ⚠️ TensorBoard not initialized correctly, not logging this run. 'NoneType' object is not callable
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-no
# train: New cache created: /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/OID/Dataset/train/Dog.cache
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# val: Scanning /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-note
# val: New cache created: /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/OID/Dataset/validation/Dog.cache
# Plotting labels to train_result/monkey19/labels.jpg...
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to train_result/monkey19
# Starting training for 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10         0G      1.013      1.989      1.448          5        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.672      0.705      0.723      0.489
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10         0G      1.053       1.38      1.455          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.616      0.674      0.656      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10         0G      1.199      1.522      1.583          5        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.529      0.618       0.54      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         0G      1.375      1.751      1.722          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.449      0.447      0.444      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10         0G      1.361      1.754       1.73          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.588      0.507      0.592      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10         0G      1.292      1.583      1.657          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.678      0.731       0.75      0.471
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10         0G      1.215      1.432      1.584          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.704      0.665      0.751      0.494
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10         0G      1.148      1.263      1.531          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.753      0.731      0.805      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10         0G      1.067      1.157      1.469          3        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.816      0.799      0.853      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10         0G      1.003      1.029      1.409          4        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.852      0.779       0.87      0.628
#
# 10 epochs completed in 2.188 hours.
# Optimizer stripped from train_result/monkey19/weights/last.pt, 22.5MB
# Optimizer stripped from train_result/monkey19/weights/best.pt, 22.5MB
#
# Validating train_result/monkey19/weights/best.pt...
# Ultralytics YOLOv8.0.52 🚀 Python-3.7.10 torch-1.13.1+cu117 CPU
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        232        296      0.852      0.779       0.87      0.627
#                 Monkey        232        129      0.871      0.736      0.846       0.61
#                  Otter        232         43      0.846      0.764      0.854      0.544
#                    Dog        232        124      0.838      0.837       0.91      0.728
# Speed: 0.3ms preprocess, 44.6ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to train_result/monkey19

# %%
# !yolo task=detect mode=predict model='train_result/monkey17/weights/best.pt' conf=0.55 source='datasets/local' save=True
# Out:
# Ultralytics YOLOv8.0.52 🚀 Python-3.7.10 torch-1.13.1+cu117 CPU
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/5 /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/local/35Q5FXBRNUI6ZABWPWZFLP7ROY.jpeg: 448x640 1 Otter, 75.4ms
# image 2/5 /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/local/5YmY2dDbYjCvBnWkwoyLVc.jpeg: 448x640 (no detections), 51.1ms
# image 3/5 /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/local/635645374313681966-MK-JW-DSC-0090 Small.jpeg: 384x640 (no detections), 60.9ms
# image 4/5 /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/local/Otters_in_Singapore.jpeg: 416x640 1 Dog, 84.3ms
# image 5/5 /home/ec2-user/SageMaker/host-yolov8-on-sagemaker-endpoint/sm-notebook/datasets/local/maxresdefault.jpeg: 384x640 1 Dog, 57.8ms
# Speed: 0.3ms preprocess, 65.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict10

# %%
# !cp -r runs/detect/predict10 'test_result'

# %% [markdown]
# ## 1.1 Import Python Libraries

# %%
import os, sagemaker, subprocess, boto3
from datetime import datetime
from sagemaker import s3
from sagemaker import get_execution_role
from sagemaker.pytorch import PyTorchModel
from sagemaker.deserializers import JSONDeserializer

# %% [markdown]
# ## 1.2 Install Ultralytics for YOLOv8 model
#
# There are following models to choose from:
# 1. Object Detection:
#     - yolov8l.pt
#     - yolov8m.pt
#     - yolov8n.pt
#     - yolov8s.pt
#     - yolov8x.pt
#     - yolov8x6.pt
# 2. Segmentation:
#     - yolov8l-seg.pt
#     - yolov8m-seg.pt
#     - yolov8n-seg.pt
#     - yolov8s-seg.pt
#     - yolov8x-seg.pt
# 3. Classification:
#     - yolov8l-cls.pt
#     - yolov8m-cls.pt
#     - yolov8n-cls.pt
#     - yolov8s-cls.pt
#     - yolov8x-cls.pt
#
# For further information, check the link: https://docs.ultralytics.com

# %%
# !pip3 install ultralytics
from ultralytics import YOLO

## Choose a model:
model_name = 'yolov8l.pt'

YOLO(model_name)
os.system(f'mv {model_name} code/.')

bashCommand = "tar -cpzf  model.tar.gz code/"
process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
output, error = process.communicate()
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: ultralytics in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (8.0.52)
# Requirement already satisfied: scipy>=1.4.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.7.3)
# Requirement already satisfied: psutil in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (5.9.3)
# Requirement already satisfied: Pillow>=7.1.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.21.6)
# Requirement already satisfied: tqdm>=4.64.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (4.64.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (5.4.1)
# Requirement already satisfied: torchvision>=0.8.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.14.1)
# Requirement already satisfied: requests>=2.23.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: pandas>=1.1.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.3.5)
# Requirement already satisfied: sentry-sdk in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.16.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (3.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: thop>=0.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.7.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from ultralytics) (4.7.0.68)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from matplotlib>=3.2.2->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pandas>=1.1.4->ultralytics) (2022.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests>=2.23.0->ultralytics) (1.26.15)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from seaborn>=0.11.0->ultralytics) (4.4.0)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch>=1.7.0->ultralytics) (8.5.0.96)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->ultralytics) (65.6.3)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.7.0->ultralytics) (0.38.4)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.2->ultralytics) (1.16.0)
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8l.pt to yolov8l.pt...
#   0%|          | 0.00/83.7M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9254/2046961356.py in <module>
#       6
#       7 YOLO(model_name)
# ----> 8 os.system(f'mv {model_name} code/.')
#       9
#      10 bashCommand = "tar -cpzf  model.tar.gz code/"
#
# NameError: name 'os' is not defined

# %% [markdown]
# ## 1.3 Zip the code and model into `model.tar.gz` and upload it to specific S3 bucket
# Here permission is granted to the S3 bucket created with CDK and not any other bucket

# %%
s3_client = boto3.client('s3')
response = s3_client.list_buckets()
for bucket in response['Buckets']:
    if 'yolov8' in bucket["Name"]:
        bucket = 's3://' + bucket["Name"]

print(f'Bucket: {bucket}')
sess = sagemaker.Session(default_bucket=bucket.split('s3://')[-1])

prefix = "yolov8/demo-custom-endpoint"

# %%
sm_client = boto3.client(service_name="sagemaker")
runtime_sm_client = boto3.client(service_name="sagemaker-runtime")

account_id = boto3.client("sts").get_caller_identity()["Account"]
region = boto3.Session().region_name

role = get_execution_role()
print(f'Role: {role}')

model_data = s3.S3Uploader.upload("model.tar.gz", bucket + "/" + prefix)
print(f'Model Data: {model_data}')

# %% [markdown]
# ## 1.4 Create the SageMaker PyTorchModel

# %%
model = PyTorchModel(entry_point='inference.py',
                     model_data=model_data, 
                     framework_version='1.12', 
                     py_version='py38',
                     role=role,
                     env={'TS_MAX_RESPONSE_SIZE':'20000000', 'YOLOV8_MODEL': model_name},
                     sagemaker_session=sess)

# %% [markdown]
# ## 1.5 Deploy the model on SageMaker Endpoint:

# %%
INSTANCE_TYPE = 'ml.m5.4xlarge'
ENDPOINT_NAME = 'yolov8-pytorch-' + str(datetime.utcnow().strftime('%Y-%m-%d-%H-%M-%S-%f'))

# Store the endpoint name in the history to be accessed by 2_TestEndpoint.ipynb notebook
# %store ENDPOINT_NAME
print(f'Endpoint Name: {ENDPOINT_NAME}')

predictor = model.deploy(initial_instance_count=1, 
                         instance_type=INSTANCE_TYPE,
                         deserializer=JSONDeserializer(),
                         endpoint_name=ENDPOINT_NAME)
